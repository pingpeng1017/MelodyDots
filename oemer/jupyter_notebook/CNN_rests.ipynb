# %%
from os import remove
import random
from pathlib import Path
from PIL import Image
import pickle
import augly.image as imaugs
import numpy as np
from sklearn import svm
from sklearn.model_selection import GridSearchCV
from oemer.bbox import get_bbox, merge_nearby_bbox, draw_bounding_boxes, rm_merge_overlap_bbox
from oemer.build_label import find_example

# %%
TARGET_WIDTH = 40
TARGET_HEIGHT = 70
DISTANCE = 10

DATASET_PATH = "./ds2_dense/segmentation"

# %%
def _collect(color, out_path, samples=1000):
    out_path = Path(out_path)
    if not out_path.exists():
        out_path.mkdir()

    cur_samples = 0
    add_space = 10
    idx = 0
    while cur_samples < samples:
        arr = find_example(DATASET_PATH, color)
        if arr is None:
            continue
        arr[arr!=200] = 0
        boxes = get_bbox(arr)
        if len(boxes) > 1:
            boxes = merge_nearby_bbox(boxes, DISTANCE)
        boxes = rm_merge_overlap_bbox(boxes)
        for box in boxes:
            if idx >= samples:
                break
            print(f"{idx+1}/{samples}", end='\r')
            patch = arr[box[1]-add_space:box[3]+add_space, box[0]-add_space:box[2]+add_space]
            ratio = random.choice(np.arange(0.6, 1.3, 0.1))
            tar_w = int(ratio * patch.shape[1])
            tar_h = int(ratio * patch.shape[0])
            img = imaugs.resize(Image.fromarray(patch.astype(np.uint8)), width=tar_w, height=tar_h)

            seed = random.randint(0, 1000)
            img = imaugs.perspective_transform(img, seed=seed, sigma=3)
            img = np.where(np.array(img)>0, 255, 0)
            Image.fromarray(patch.astype(np.uint8)).save(out_path / f"{idx}.png")
            idx += 1

        cur_samples += len(boxes)
    print()

# %%
def collect_data(samples=1000):
    color_map = {
#         74: "sharp",
#         70: "flat",
#         72: "natural",
        97: 'rest_whole',
        98: 'rest_half',
        99: 'rest_quarter',
        100: 'rest_8th',
#         101: 'rest_16th',
#         102: 'rest_32nd',
#         103: 'rest_64th',
#         104: 'rest_128th'
        # 10: 'gclef',
        # 13: 'fclef',
        # 추가: time signature에 해당하는 데이터
#         21: 'timesig_0',
#         22: 'timesig_1',
#         23: 'timesig_2',
#         24: 'timesig_3',
#         25: 'timesig_4',
#         26: 'timesig_5',
#         27: 'timesig_6',
#         28: 'timesig_7',
#         29: 'timesig_8',
#         30: 'timesig_9',
#         33: 'timesig_4_4',
#         34: 'timesig_2_2',
    }
    
    for color, name in color_map.items():
        print('Current', name)
        _collect(color, f"./ds2_dense/train_data/{name}", samples=samples)
        _collect(color, f"./ds2_dense/val_data/{name}", samples=samples)  # 검증 데이터 생성 및 저장
        _collect(color, f"./ds2_dense/test_data/{name}", samples=samples)

# %%
def train(folders):
    class_map = {idx: Path(ff).name for idx, ff in enumerate(folders)}
    train_data = []
    train_labels = []
    val_data = []  # 추가: 검증 데이터
    val_labels = []  # 추가: 검증 데이터
    samples = None
    print("Loading data")
    for cidx, folder in enumerate(folders):
        folder = Path(folder)
        idx = 0
        for ff in folder.glob('*.png'):
            if samples is not None and idx >= samples:
                break
            img = Image.open(ff).resize((TARGET_WIDTH, TARGET_HEIGHT))
            arr = np.array(img)
            if idx % 5 == 0:  # 추가: 검증 데이터를 위해 1/5 비율로 분할
                val_data.append(arr)
                val_labels.append(cidx)
            else:
                train_data.append(arr)
                train_labels.append(cidx)
            idx += 1

    train_data = np.array(train_data)
    train_labels = np.array(train_labels)
    val_data = np.array(val_data)  # 추가: 검증 데이터
    val_labels = np.array(val_labels)  # 추가: 검증 데이터

    model = models.Sequential([
    layers.Input(shape=(TARGET_HEIGHT, TARGET_WIDTH, 1)),
    
    # 첫 번째 Convolutional Layer
    layers.Conv2D(64, (3, 3), activation='relu', padding='same'),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.2),
    
    # 두 번째 Convolutional Layer
    layers.Conv2D(128, (3, 3), activation='relu', padding='same'),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.2),
    
    # 세 번째 Convolutional Layer
    layers.Conv2D(256, (3, 3), activation='relu', padding='same'),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.2),
    
    # 네 번째 Convolutional Layer
    layers.Conv2D(512, (3, 3), activation='relu', padding='same'),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.2),
    
    # Fully Connected Layer
    layers.Flatten(),
    layers.Dense(256, activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(len(folders), activation='softmax')
])

    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    history = model.fit(train_data, train_labels, validation_data=(val_data, val_labels), epochs=20, batch_size=32)
    return model, class_map, history

# %%
def test_tf(model, folders):
    test_x = []
    test_y = []
    print("Loading data")
    for cidx, folder in enumerate(folders):
        folder = Path(folder)
        files = list(folder.iterdir())
        random.shuffle(files)
        for ff in files:
            img = Image.open(ff).resize((TARGET_WIDTH, TARGET_HEIGHT))
            arr = np.array(img)
            test_x.append(arr)
            test_y.append(cidx)

    test_x = np.array(test_x)[..., np.newaxis]
    test_y = np.array(test_y)
    test_result = []
    batch_size = 32
    class_correct = [0] * len(folders)
    class_total = [0] * len(folders)
    for idx in range(0, len(test_x), batch_size):
        data = test_x[idx:idx+batch_size]
        pred = model.predict(data)
        pidx = np.argmax(pred, axis=-1)
        test_result.extend(list(pidx))
        
        for i in range(len(pidx)):
            class_total[test_y[idx+i]] += 1
            if pidx[i] == test_y[idx+i]:
                class_correct[pidx[i]] += 1

    test_result = np.array(test_result)
    tp = test_result[test_result==test_y].size
    acc = tp / len(test_y)
    print("Accuracy: ", acc)
    
    class_accuracies = [correct / total if total > 0 else 0 for correct, total in zip(class_correct, class_total)]

    # 막대 그래프로 클래스별 정확도 시각화
    plt.figure(figsize=(10, 6))
    class_names = [folder.split("/")[-1] for folder in folders]
    plt.bar(class_names, class_accuracies, color='skyblue')
    plt.xlabel('Class', fontsize=12)
    plt.ylabel('Accuracy', fontsize=12)
    plt.title('Class-wise Accuracy', fontsize=14)
    plt.xticks(rotation=45)
    plt.ylim(0, 1)
    plt.tight_layout()
    plt.show()

# %%
def predict(region, model_name):
    if np.max(region) == 1:
        region *= 255
    m_info = pickle.load(open(f"sklearn_models/{model_name}.model", "rb"))
    model = m_info['model']
    w = m_info['w']
    h = m_info['h']
    region = Image.fromarray(region.astype(np.uint8)).resize((w, h))
    pred = model.predict(np.array(region).reshape(1, -1))
    return m_info['class_map'][pred[0]]

# %%
samples = 1000

collect_data(samples=samples)

folders = ["rest_whole", "rest_half", "rest_quarter", "rest_8th"]
model_name = "rests"
# Out:
# Current rest_whole
# 1000/1000
# 1000/1000
# 1000/1000
# Current rest_half
# 1000/1000
# 1000/1000
# 1000/1000
# Current rest_quarter
# 1000/1000
# 1000/1000
# 1000/1000
# Current rest_8th
# 1000/1000
# 1000/1000
# 1000/1000

# %%
from tensorflow.keras import models, layers
model, class_map, history = train([f"ds2_dense/train_data/{folder}" for folder in folders])
# Out:
# Loading data
# Epoch 1/20
# 100/100 [==============================] - 20s 186ms/step - loss: 0.7256 - accuracy: 0.7550 - val_loss: 0.3369 - val_accuracy: 0.7975
# Epoch 2/20
# 100/100 [==============================] - 18s 176ms/step - loss: 0.3504 - accuracy: 0.7950 - val_loss: 0.3141 - val_accuracy: 0.7800
# Epoch 3/20
# 100/100 [==============================] - 17s 169ms/step - loss: 0.3192 - accuracy: 0.8122 - val_loss: 0.2881 - val_accuracy: 0.8175
# Epoch 4/20
# 100/100 [==============================] - 18s 178ms/step - loss: 0.3126 - accuracy: 0.8144 - val_loss: 0.3964 - val_accuracy: 0.7850
# Epoch 5/20
# 100/100 [==============================] - 18s 178ms/step - loss: 0.2976 - accuracy: 0.8247 - val_loss: 0.2802 - val_accuracy: 0.8388
# Epoch 6/20
# 100/100 [==============================] - 17s 174ms/step - loss: 0.2773 - accuracy: 0.8409 - val_loss: 0.2503 - val_accuracy: 0.8550
# Epoch 7/20
# 100/100 [==============================] - 18s 177ms/step - loss: 0.2890 - accuracy: 0.8297 - val_loss: 0.2618 - val_accuracy: 0.8487
# Epoch 8/20
# 100/100 [==============================] - 17s 169ms/step - loss: 0.2603 - accuracy: 0.8397 - val_loss: 0.2190 - val_accuracy: 0.8600
# Epoch 9/20
# 100/100 [==============================] - 17s 172ms/step - loss: 0.2491 - accuracy: 0.8422 - val_loss: 0.2270 - val_accuracy: 0.8575
# Epoch 10/20
# 100/100 [==============================] - 18s 175ms/step - loss: 0.2352 - accuracy: 0.8475 - val_loss: 0.2064 - val_accuracy: 0.8637
# Epoch 11/20
# 100/100 [==============================] - 18s 179ms/step - loss: 0.2402 - accuracy: 0.8397 - val_loss: 0.2125 - val_accuracy: 0.8662
# Epoch 12/20
# 100/100 [==============================] - 18s 181ms/step - loss: 0.2354 - accuracy: 0.8503 - val_loss: 0.2164 - val_accuracy: 0.8687
# Epoch 13/20
# 100/100 [==============================] - 18s 178ms/step - loss: 0.2521 - accuracy: 0.8469 - val_loss: 0.2590 - val_accuracy: 0.8550
# Epoch 14/20
# 100/100 [==============================] - 18s 177ms/step - loss: 0.2494 - accuracy: 0.8500 - val_loss: 0.2393 - val_accuracy: 0.8675
# Epoch 15/20
# 100/100 [==============================] - 18s 180ms/step - loss: 0.2340 - accuracy: 0.8537 - val_loss: 0.2436 - val_accuracy: 0.8587
# Epoch 16/20
# 100/100 [==============================] - 18s 176ms/step - loss: 0.2338 - accuracy: 0.8491 - val_loss: 0.2164 - val_accuracy: 0.8575
# Epoch 17/20
# 100/100 [==============================] - 18s 175ms/step - loss: 0.2288 - accuracy: 0.8578 - val_loss: 0.2165 - val_accuracy: 0.8525
# Epoch 18/20
# 100/100 [==============================] - 18s 177ms/step - loss: 0.2192 - accuracy: 0.8603 - val_loss: 0.2415 - val_accuracy: 0.8400
# Epoch 19/20
# 100/100 [==============================] - 19s 187ms/step - loss: 0.2408 - accuracy: 0.8566 - val_loss: 0.2181 - val_accuracy: 0.8612
# Epoch 20/20
# 100/100 [==============================] - 19s 190ms/step - loss: 0.2227 - accuracy: 0.8528 - val_loss: 0.3598 - val_accuracy: 0.8487

# %%
import matplotlib.pyplot as plt

# 훈련 과정에서의 손실, 정확도, 검증 손실, 검증 정확도 값을 가져옴
loss = history.history['loss']
accuracy = history.history['accuracy']
val_loss = history.history['val_loss']
val_accuracy = history.history['val_accuracy']

# 그래프 생성 및 표시
plt.figure(figsize=(12, 4))

# 손실 그래프
plt.subplot(1, 2, 1)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss', color='red')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()

# 정확도 그래프
plt.subplot(1, 2, 2)
plt.plot(accuracy, label='Training Accuracy', color='orange')
plt.plot(val_accuracy, label='Validation Accuracy', color='purple')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import accuracy_score
test_tf(model, [f"ds2_dense/test_data/{folder}" for folder in folders])
# Out:
# Loading data
# 1/1 [==============================] - 0s 149ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 53ms/step
# Accuracy:  0.82675

# %%
output = {'model': model, 'w': TARGET_WIDTH, 'h': TARGET_HEIGHT, 'class_map': class_map}
pickle.dump(output, open(f"sklearn_models/{model_name}.model", "wb"))
